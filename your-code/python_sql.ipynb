# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
str_conn='mysql+pymysql://root:****@localhost:3306/sentences'

cursor=create_engine(str_conn)

# %%
datos=pd.read_csv(r'C:\Users\jvaym\Desktop\IRONHACK\Semana4\frases_v6.csv') #Tabla Frases
datos
# Out:
#                                                    Frase  \
# 0      Un amigo es uno que lo sabe todo de ti y a pes...
# 1      Si sientes que todo perdió su sentido, siempre...
# 2      La amistad es más difícil y más rara que el am...
# 3      Ama hasta que te duela. Si te duele es buena s...
# 4      Un hermano puede no ser un amigo, pero un amig...
# ...                                                  ...
# 10107                   Poder olvidar significa cordura.
# 10108  No holgazanees y invita a la inspiración; sal ...
# 10109  Los dioses tramaron desventuras para que los h...
# 10110  Dije "je t’aime", en lo de amar sobran los adv...
# 10111     No hay autoridad moral como la del sacrificio.
#
#                                                    Autor                 Cat1  \
# 0      Elbert Hubbard (1856-1915) Ensayista estadouni...         SENTIMIENTOS
# 1      Emerson (1803-1882) Poeta y pensador estadouni...         SENTIMIENTOS
# ...

# %%
datos.to_sql(name='sentences', con=cursor, if_exists='replace', index=False) #Tabla Frases

# %%
datos2 = pd.read_csv(r'C:\Users\jvaym\Desktop\IRONHACK\Semana4\Deep_SentencesETL\Data\autores_v2.csv')
datos2 # Tabla Autores
# Out:
#                                                  Autor               Nombre  \
# 0                                               Refrán               Refrán
# 1    Oscar Wilde (1854-1900) Dramaturgo y novelista...          Oscar Wilde
# 2         Aristóteles (384 AC-322 AC) Filósofo griego.          Aristóteles
# 3                    Séneca (2 AC-65) Filósofo latino.               Séneca
# 4    William Shakespeare (1564-1616) Escritor britá...  William Shakespeare
# ..                                                 ...                  ...
# 860  Nicanor Parra (1914-?) Poeta, matemático y fís...        Nicanor Parra
# 861  Álvaro Mutis (1923-2013) Novelista y poeta col...         Álvaro Mutis
# 862    Charlotte Brontë (1816-1855) Novelista inglesa.     Charlotte Brontë
# 863  Horacio Quiroga (1878-1937) Cuentista, dramatu...      Horacio Quiroga
# 864    Antonio Tabucchi (1943-2012) Escritor italiano.     Antonio Tabucchi
#
#                                                   Link
# ...

# %%
datos2.to_sql(name='autores', con=cursor, if_exists='replace', index=False) #Tabla Autores
